# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
from itertools import combinations_with_replacement

# %% [markdown]
# ### 1. 哈代函数$f$与近似多项式$g$的$n-best$结果
# **_n-best AFD approximation of Hardy space function $f$ and approximation polynomial $g$_**
#
# $\Vert f\Vert^2=E_f$,$\Vert g\Vert^2=E_g$ with $\frac{\Vert f-g\Vert^2}{\Vert f\Vert^2}=\delta$. Let $\textbf{a}_f$, $\textbf{a}_g$ be the n-best AFD vector of $f$ and $g$ respectively. Let $\vert \textbf{a}_f-\textbf{a}_g \vert=\epsilon$

# %%
##\\f-g\\^2=0.5;g=z;1-best result

# %%
## growth curve
x=np.linspace(0,1,100);rs=np.array([np.complex(np.cos(z*2*np.pi),np.sin(z*2*np.pi)) for z in x])
r,theta=np.linspace(0,1,100),np.linspace(0,2*np.pi,100)
R,Theta=np.meshgrid(r,theta)
X,Y=R*np.cos(Theta),R*np.sin(Theta)

#Z=np.array([[maxf2ab(np.complex(i*np.cos(j),i*np.sin(j)),a,b) for i in r] for j in theta])
#f=z^2+az+b
a=1;b=0
Z=np.array([np.array([np.abs(np.complex(i*np.cos(j),i*np.sin(j))**2+a*np.complex(i*np.cos(j),i*np.sin(j))+b) for j in theta]).max() 
            for i in r])
plt.plot(r,Z/2)
a=1;b=1
Z=np.array([np.array([np.abs(np.complex(i*np.cos(j),i*np.sin(j))**2+a*np.complex(i*np.cos(j),i*np.sin(j))+b) for j in theta]).max() 
            for i in r])
plt.plot(r,Z/3)
a=0;b=0
Z=np.array([np.array([np.abs(np.complex(i*np.cos(j),i*np.sin(j))**2+a*np.complex(i*np.cos(j),i*np.sin(j))+b) for j in theta]).max() 
            for i in r])
plt.plot(r,Z)
#plt.contour(X,Y,Z)

# %% [markdown]
# ### 2. 多项式拟合和有理拟合
# **_Polynomial and rational approximation_**
